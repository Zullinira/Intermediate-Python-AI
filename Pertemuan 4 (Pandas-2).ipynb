# %% [markdown]
# # Pandas-2 Continues..

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("My Uber Drives - 2016.csv")

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.to_csv('data_baru.csv')

# %% [markdown]
# .any() = untuk ngeflek true and flase. dibalikkan?

# %% [markdown]
# # 5. Groupby Summarize

# %% [markdown]
# For each start location, find the mean distance of the trip

# %%
data.groupby("START*")["MILES*"].agg(["mean"])
#tampilkan dengan start dan rata2 miles
# Out:
#                                   mean
# START*
# Agnew                         2.775000
# Almond                       15.200000
# Apex                          5.341176
# Arabi                        17.000000
# Arlington                     4.900000
# Arlington Park at Amberly     1.300000
# Asheville                   143.850000
# Austin                      136.000000
# Banner Elk                   12.375000
# Bellevue                     12.900000
# Berkeley                     14.375000
# Boone                       102.000000
# Briar Meadow                  9.600000
# Bryson City                  20.820000
# Burtrose                      4.800000
# CBD                           3.850000
# Capitol One                   9.450000
# Cary                          8.911940
# Central                       1.950000
# Chalmette                     1.100000
# Chapel Hill                  20.150000
# Chessington                   3.350000
# College Avenue                2.600000
# ...

# %%
#find the mean and total distance travelled
data.groupby("START*")["MILES*"].agg(["mean","sum","count"]).sort_values('count',ascending=False)
# Out:
#                             mean     sum  count
# START*
# Cary                    8.911940  1791.3    201
# Unknown Location       13.354730  1976.5    148
# Morrisville             7.902353   671.7     85
# Whitebridge             4.020588   273.4     68
# Islamabad               7.038596   401.2     57
# Durham                 10.389189   384.4     37
# Lahore                  6.616667   238.2     36
# Raleigh                15.464286   433.0     28
# Kar?chi                 4.262963   115.1     27
# Apex                    5.341176    90.8     17
# Westpark Place          2.182353    37.1     17
# Berkeley               14.375000   230.0     16
# Midtown                 7.228571   101.2     14
# R?walpindi             22.545455   248.0     11
# Kissimmee              14.845455   163.3     11
# Kenner                 10.427273   114.7     11
# New Orleans            16.230000   162.3     10
# Emeryville              5.230000    52.3     10
# ...

# %%
data["START*"].value_counts()
# Out:
# Cary                          201
# Unknown Location              148
# Morrisville                    85
# Whitebridge                    68
# Islamabad                      57
# Durham                         37
# Lahore                         36
# Raleigh                        28
# Kar?chi                        27
# Apex                           17
# Westpark Place                 17
# Berkeley                       16
# Midtown                        14
# Kissimmee                      11
# R?walpindi                     11
# Kenner                         11
# Emeryville                     10
# New Orleans                    10
# Downtown                        9
# Central                         8
# Edgehill Farms                  8
# Orlando                         8
# Colombo                         8
# Banner Elk                      8
# San Francisco                   8
# The Drag                        7
# Hazelwood                       7
# ...

# %% [markdown]
# # Save DataFrame into CSV

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
data.to_csv("data_baru.csv")

# %% [markdown]
# saving df without index

# %%
data.to_csv("data_baru2.csv", index = False)

# %% [markdown]
# # Handling Missing Value

# %%
import numpy as np

# %%
new_df = pd.DataFrame({'col_a': [1,2,4,1, np.nan, np.nan, 5],
                       'col_b': [3,7, np.nan, 9, None, 5, 8],
                       'col_c': ['a', '?', 'x', 'y', '--', np.nan, 'r'],
                       'col_d': [True, True, np.nan, None, False, True, False]})

# %%
new_df
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0     ?   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN    --  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
new_df['col_c'].unique()
# Out:
# array(['a', '?', 'x', 'y', '--', nan, 'r'], dtype=object)

# %%
new_df.to_csv('data_saya.csv', index=False)

# %% [markdown]
# # Find Missing Value

# %% [markdown]
# np.nan, None and NaT (for datetime64[ns] types) are standard missing value for Pandas.

# %% [markdown]
# Pandas provides `isnull()`, `isna()` functions to detect missing values. Both of them do the same thing.

# %%
new_df.shape
# Out:
# (7, 4)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
# col_a    5 non-null float64
# col_b    5 non-null float64
# col_c    6 non-null object
# col_d    5 non-null object
# dtypes: float64(2), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# arti info diatas :
# 1. Terdapat 7 baris dengan 4 kolom
# 2. col_a berisi 5 dari 7 (missing 2)
# 3. col_b bersisi 5 dari 7 (missing 2)
# dst

# %%
new_df.isna()
#True = bagian yang missing value
# Out:
#    col_a  col_b  col_c  col_d
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False   True  False   True
# 3  False  False  False   True
# 4   True   True  False  False
# 5   True  False   True  False
# 6  False  False  False  False

# %%
new_df.isna().any() 
# true pada any mksd ny jika ada 1 saja baris pada suatu kolom yang punya missing value maka akan terbaca true
# Out:
# col_a    True
# col_b    True
# col_c    True
# col_d    True
# dtype: bool

# %%
new_df.isna().sum() #jumlah baris yang ada  missing value dalam suatu kolom
# Out:
# col_a    2
# col_b    2
# col_c    1
# col_d    2
# dtype: int64

# %% [markdown]
# Pandas provides `isnull()`, `isna()` functions to detect missing values. Both of them do the same thing.

# %% [markdown]
# If we know what kind of characters used as missing values in the dataset, we can handle them by creating the dataframe using `na_values` parameter:

# %%
missing_values =["?","--"] #tanda ? dan -- yang berbeda dari yang lain pada kolom, dimasukkan sebagai missing value
df2=pd.read_csv("data_saya.csv", na_values = missing_values)

# %%
df2.isna().sum() #ditampilkan missing value baru
# Out:
# col_a    2
# col_b    2
# col_c    3
# col_d    2
# dtype: int64

# %%
df2
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y    NaN
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %% [markdown]
# Another option is to use pandas replace() function to handle these values after a dataframe is created:

# %%
df3 = new_df.replace({"?":np.nan,"--":np.nan})

# %%
df3.isna().sum()
# Out:
# col_a    2
# col_b    2
# col_c    3
# col_d    2
# dtype: int64

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %% [markdown]
# Comparre to original df

# %%
new_df.isna().sum()
# Out:
# col_a    2
# col_b    2
# col_c    1
# col_d    2
# dtype: int64

# %% [markdown]
# # Drop Missing Value

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %% [markdown]
# We can drop a row or column with missing values using dropna() function. We can use some condition:\
# how='any' : drop if there is any missing value\
# how='all' : drop if all values are missing

# %%
df3.dropna(axis=0, how='all', inplace=True) 
#drop jika semua (x=0adlaah baris) merupakan mising value

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    2.6    NaN   NaN  False
# 5    2.6    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df3.dropna(axis=0, how='any')
#jika ada 1 saja missing value di baris (x=0) maka akan di drop
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 6    5.0    8.0     r  False

# %% [markdown]
# We can use 'thresh' parameter to set a threshold for missing values in order for a row/column to be dropped. Thresh is the amount of non-na value

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df3.dropna(axis=0,thresh=3)
#fungsi thresh?
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 3    1.0    9.0     y   None
# 6    5.0    8.0     r  False

# %% [markdown]
# # Replacing missing values

# %% [markdown]
# `fillna()` function in Pandas is used to replace missing values with another values.\
# Missing values can be replaced by:
# 1. Special value
# 2. Aggregate value, such as mean, median, etc

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df5=df3.fillna(0) #missing value diganti dengan angka 0
df5
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0     0   True
# 2    4.0    0.0     x      0
# 3    1.0    9.0     y      0
# 4    0.0    0.0     0  False
# 5    0.0    5.0     0   True
# 6    5.0    8.0     r  False

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %% [markdown]
# ### mengisi missing value pada kolom tertentu

# %%
df3['col_a'].mean()
# Out:
# 2.6

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
#kolom di balik
#bacaan [:, ::-1] = semua baris(:), kolom dibalik(::-1)
df3.iloc[:, ::-1]# [m:n:s] m : inclusive, n : exclusive , s : step (default: 1)
# Out:
#    col_d col_c  col_b  col_a
# 0   True     a    3.0    1.0
# 1   True   NaN    7.0    2.0
# 2    NaN     x    NaN    4.0
# 3   None     y    9.0    1.0
# 4  False   NaN    NaN    NaN
# 5   True   NaN    5.0    NaN
# 6  False     r    8.0    5.0

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
#semua baris di kolom index 0 diisi dengan rata2nya
df3.iloc[:,0] =df3.iloc[:,0].fillna(df3.iloc[:,0].mean())

# %%
df3
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    2.6    NaN   NaN  False
# 5    2.6    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
#ulang dan simpan dengan nama baru
#repalce
dfx =new_df.replace({"?":np.nan,"--":np.nan})
dfx
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
dfx['col_a']=dfx['col_a'].fillna(dfx['col_a'].mode()[0])
#mengisi col-a yang missing value dengan modus pada kolom indeks 0(col_a)

# %%
dfx
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    1.0    NaN   NaN  False
# 5    1.0    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df7=new_df.replace({"?":np.nan,"--":np.nan})

# %%
df7
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df8=new_df.replace({"?":np.nan,"--":np.nan})

# %%
df8
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %% [markdown]
# Take the last seen values by using `ffill` (forward fill)

# %%
df8.fillna(method='ffill',inplace=True)
df8
#ffill=forward fill = yang 'didepannya'(yg missingvalue) akan diisi dengan nilai disebelumnya
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0     a   True
# 2    4.0    7.0     x   True
# 3    1.0    9.0     y   True
# 4    1.0    9.0     y  False
# 5    1.0    5.0     y   True
# 6    5.0    8.0     r  False

# %%
df9 = new_df.replace({"?": np.nan, "--": np.nan})
df9
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0   NaN   True
# 2    4.0    NaN     x    NaN
# 3    1.0    9.0     y   None
# 4    NaN    NaN   NaN  False
# 5    NaN    5.0   NaN   True
# 6    5.0    8.0     r  False

# %%
df9.fillna(method='bfill', inplace=True)
#yang sebelumnya (yg mising value) akan diisi dengan  yg sesudahnya

# %%
df9
# Out:
#    col_a  col_b col_c  col_d
# 0    1.0    3.0     a   True
# 1    2.0    7.0     x   True
# 2    4.0    9.0     x  False
# 3    1.0    9.0     y  False
# 4    5.0    5.0     r  False
# 5    5.0    5.0     r   True
# 6    5.0    8.0     r  False
